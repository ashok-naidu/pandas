# %%
#lab 29 - Read and Write Operations on CSV Files using Pandas

## Problem

# 1. Read 'pokemon.csv' file using pandas library and display data records. 

# 2. Skip 1st ,3rd ,5t ,7th row while reading the file.

# %%
## Solution

import pandas as pd

pd.read_csv("pokemon.csv", skiprows =[1,3,5,7])
# Out:
#        #                       Name   Type 1  Type 2  Total  HP  Attack  \
# 0      2                    Ivysaur    Grass  Poison    405  60      62
# 1      4      VenusaurMega Venusaur    Grass  Poison    625  80     100
# 2      6                 Charmeleon     Fire     NaN    405  58      64
# 3      8  CharizardMega Charizard X     Fire  Dragon    634  78     130
# 4      9  CharizardMega Charizard Y     Fire  Flying    634  78     104
# ..   ...                        ...      ...     ...    ...  ..     ...
# 791  796                    Diancie     Rock   Fairy    600  50     100
# 792  797        DiancieMega Diancie     Rock   Fairy    700  50     160
# 793  798        HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 794  799         HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 795  800                  Volcanion     Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...
